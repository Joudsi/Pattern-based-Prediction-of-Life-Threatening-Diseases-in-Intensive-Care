# %%
import pandas as pd
data = pd.read_csv('/Users/joudsi/Desktop/output.csv')

# %%
data.columns.values
# Out:
# array(['Unnamed: 0', 'subject_id', 'hadm_id', 'icu', 'amdission_age',
#        'gender', 'thirty_day_mort', 'heartrate_mean', 'meanbp_mean',
#        'sysbp_mean', 'tempc_mean', 'spo2_mean', 'resprate_mean',
#        'diasbp_mean', 'creatinine_mean', 'potassium_mean', 'sodium_mean',
#        'chloride_mean', 'bicarbonate_mean', 'hematocrit_mean', 'wbc_mean',
#        'glucose_mean', 'lactate_mean', 'aniongap_mean', 'albumin_mean',
#        'bands_mean', 'bilirubin_mean', 'hemoglobin_mean', 'ptt_mean',
#        'inr_mean', 'pt_mean', 'bun_mean', 'is_AKI', 'is_Betablocker'],
#       dtype=object)

# %%
data.head()
# Out:
#    Unnamed: 0  subject_id  hadm_id     icu  amdission_age  gender  \
# 0           0       26264   163486  211181        58.5394       0
# 1           1       86580   145497  285183        53.3505       0
# 2           2       28410   146362  282162        80.7914       0
# 3           3       61683   197678  237242        61.1226       0
# 4           4       23626   166653  230856        61.6232       0
#
#    thirty_day_mort  heartrate_mean  meanbp_mean  sysbp_mean       ...        \
# 0                1       88.464286    90.333333  143.200000       ...
# 1                1      115.125000    80.260870  111.217391       ...
# 2                1       91.909091    70.035714  120.413793       ...
# 3                1      106.521739    76.772727  117.000000       ...
# 4                0       44.896552    73.180328  107.344262       ...
#
#    albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  ptt_mean  \
# 0           NaN         NaN             NaN        15.400000      24.9
# 1           NaN         NaN             0.4         9.600000       NaN
# 2           NaN         NaN             NaN         6.866667      37.1
# 3           3.0         NaN             0.2        12.000000      27.3
# 4           NaN         NaN             0.7        11.866667      26.1
#
#    inr_mean  pt_mean  bun_mean  is_AKI  is_Betablocker
# 0       1.2     13.2       8.0       0               1
# 1       NaN      NaN      18.0       0               0
# 2       1.3     15.1      18.0       1               0
# 3       1.1     11.4     132.5       1               0
# 4       1.1     13.1      21.0       0               0
#
# [5 rows x 34 columns]

# %%
data.describe()
# Out:
#          Unnamed: 0    subject_id        hadm_id            icu  \
# count  12467.000000  12467.000000   12467.000000   12467.000000
# mean    6233.000000  38630.683725  149823.922515  250382.545841
# std     3599.057238  29480.507137   28797.845972   28802.744521
# min        0.000000      3.000000  100003.000000  200003.000000
# 25%     3116.500000  14209.500000  125266.000000  225610.500000
# 50%     6233.000000  28140.000000  149618.000000  250740.000000
# 75%     9349.500000  63363.500000  175202.500000  275543.500000
# max    12466.000000  99991.000000  199999.000000  299998.000000
#
#        amdission_age        gender  thirty_day_mort  heartrate_mean  \
# count   12467.000000  12467.000000     12467.000000    12433.000000
# mean       66.831487      0.467554         0.410203       88.337630
# std        16.628257      0.498966         0.491890       16.760893
# min        16.980400      0.000000         0.000000       34.844828
# 25%        55.653800      0.000000         0.000000       76.200000
# 50%        68.932800      0.000000         0.000000       87.400000
# 75%        80.016500      1.000000         1.000000       99.620690
# max        91.400000      1.000000         1.000000      163.875000
#
#         meanbp_mean    sysbp_mean       ...        albumin_mean   bands_mean  \
# count  12432.000000  12422.000000       ...         6100.000000  2710.000000
# mean      76.168888    116.463336       ...            2.958234    10.588819
# std       11.337419     17.244430       ...            0.675008    10.441675
# min       24.535714     46.000000       ...            1.000000     0.900000
# 25%       68.392469    104.105733       ...            2.500000     3.000000
# 50%       74.763257    113.500000       ...            2.950000     7.000000
# 75%       82.875000    126.912055       ...            3.400000    15.000000
# max      133.000000    195.343750       ...            5.600000    69.000000
#
#        bilirubin_mean  hemoglobin_mean      ptt_mean      inr_mean  \
# count     7403.000000     12333.000000  11271.000000  11315.000000
# mean         2.234980        10.654637     38.966710      1.625585
# std          5.140846         1.873165     19.295306      1.066585
# min          0.100000         4.000000     14.400000      0.800000
# 25%          0.400000         9.335714     27.500000      1.150000
# 50%          0.700000        10.450000     32.450000      1.300000
# 75%          1.600000        11.825000     42.300000      1.650000
# max         80.900000        19.600000    150.000000     32.400000
#
#             pt_mean      bun_mean        is_AKI  is_Betablocker
# count  11316.000000  12353.000000  12467.000000     12467.00000
# mean      16.776565     32.733548      0.427208         0.48103
# std        7.503983     24.974152      0.494693         0.49966
# min        9.300000      2.000000      0.000000         0.00000
# 25%       13.300000     16.000000      0.000000         0.00000
# 50%       14.587500     25.000000      0.000000         0.00000
# 75%       17.066667     42.000000      1.000000         1.00000
# max      150.000000    265.000000      1.000000         1.00000
#
# [8 rows x 34 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12467 entries, 0 to 12466
# Data columns (total 34 columns):
# Unnamed: 0          12467 non-null int64
# subject_id          12467 non-null int64
# hadm_id             12467 non-null int64
# icu                 12467 non-null int64
# amdission_age       12467 non-null float64
# gender              12467 non-null int64
# thirty_day_mort     12467 non-null int64
# heartrate_mean      12433 non-null float64
# meanbp_mean         12432 non-null float64
# sysbp_mean          12422 non-null float64
# tempc_mean          12256 non-null float64
# spo2_mean           12410 non-null float64
# resprate_mean       12423 non-null float64
# diasbp_mean         12421 non-null float64
# creatinine_mean     12354 non-null float64
# potassium_mean      12366 non-null float64
# sodium_mean         12364 non-null float64
# chloride_mean       12355 non-null float64
# bicarbonate_mean    12337 non-null float64
# hematocrit_mean     12348 non-null float64
# wbc_mean            12323 non-null float64
# glucose_mean        12363 non-null float64
# lactate_mean        9106 non-null float64
# aniongap_mean       12287 non-null float64
# albumin_mean        6100 non-null float64
# bands_mean          2710 non-null float64
# bilirubin_mean      7403 non-null float64
# hemoglobin_mean     12333 non-null float64
# ptt_mean            11271 non-null float64
# inr_mean            11315 non-null float64
# pt_mean             11316 non-null float64
# bun_mean            12353 non-null float64
# is_AKI              12467 non-null int64
# is_Betablocker      12467 non-null int64
# dtypes: float64(26), int64(8)
# memory usage: 3.2 MB

# %%
data.shape
# Out:
# (12467, 34)

# %%
# data['ptt_min'].fillna(0, inplace = True)

data['heartrate_mean'].fillna(data['heartrate_mean'].mean(), inplace = True)       
          
data['meanbp_mean'].fillna(data['meanbp_mean'].mean(), inplace = True)          
           
data['sysbp_mean'].fillna(data['sysbp_mean'].mean(), inplace = True)           
          
data['tempc_mean'].fillna(data['tempc_mean'].mean(), inplace = True)           
           
data['spo2_mean'].fillna(data['spo2_mean'].mean(), inplace = True)            
      
data['resprate_mean'].fillna(data['resprate_mean'].mean(), inplace = True)        
         
data['diasbp_mean'].fillna(data['diasbp_mean'].mean(), inplace = True)          

# data['glucose_mean_vitals'].fillna(data['glucose_mean_vitals'].mean(), inplace = True)  
    
data['creatinine_mean'].fillna(data['creatinine_mean'].mean(), inplace = True)       
     
data['potassium_mean'].fillna(data['potassium_mean'].mean(), inplace = True)        
   
data['sodium_mean'].fillna(data['sodium_mean'].mean(), inplace = True)           
       
data['chloride_mean'].fillna(data['chloride_mean'].mean(), inplace = True)         

data['bicarbonate_mean'].fillna(data['bicarbonate_mean'].mean(), inplace = True)      
     
data['hematocrit_mean'].fillna(data['hematocrit_mean'].mean(), inplace = True)       
         
data['wbc_mean'].fillna(data['wbc_mean'].mean(), inplace = True)              
        
data['glucose_mean'].fillna(data['glucose_mean'].mean(), inplace = True)          
 
data['lactate_mean'].fillna(data['lactate_mean'].mean(), inplace = True)         
     
data['aniongap_mean'].fillna(data['aniongap_mean'].mean(), inplace = True)         
    
data['albumin_mean'].fillna(data['albumin_mean'].mean(), inplace = True)         
       
data['bands_mean'].fillna(data['bands_mean'].mean(), inplace = True)           

data['bilirubin_mean'].fillna(data['bilirubin_mean'].mean(), inplace = True)       
   
data['hemoglobin_mean'].fillna(data['hemoglobin_mean'].mean(), inplace = True)       
      
data['ptt_mean'].fillna(data['ptt_mean'].mean(), inplace = True)              
          
data['inr_mean'].fillna(data['inr_mean'].mean(), inplace = True)              
           
data['pt_mean'].fillna(data['pt_mean'].mean(), inplace = True)               
            
data['bun_mean'].fillna(data['bun_mean'].mean(), inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12467 entries, 0 to 12466
# Data columns (total 34 columns):
# Unnamed: 0          12467 non-null int64
# subject_id          12467 non-null int64
# hadm_id             12467 non-null int64
# icu                 12467 non-null int64
# amdission_age       12467 non-null float64
# gender              12467 non-null int64
# thirty_day_mort     12467 non-null int64
# heartrate_mean      12467 non-null float64
# meanbp_mean         12467 non-null float64
# sysbp_mean          12467 non-null float64
# tempc_mean          12467 non-null float64
# spo2_mean           12467 non-null float64
# resprate_mean       12467 non-null float64
# diasbp_mean         12467 non-null float64
# creatinine_mean     12467 non-null float64
# potassium_mean      12467 non-null float64
# sodium_mean         12467 non-null float64
# chloride_mean       12467 non-null float64
# bicarbonate_mean    12467 non-null float64
# hematocrit_mean     12467 non-null float64
# wbc_mean            12467 non-null float64
# glucose_mean        12467 non-null float64
# lactate_mean        12467 non-null float64
# aniongap_mean       12467 non-null float64
# albumin_mean        12467 non-null float64
# bands_mean          12467 non-null float64
# bilirubin_mean      12467 non-null float64
# hemoglobin_mean     12467 non-null float64
# ptt_mean            12467 non-null float64
# inr_mean            12467 non-null float64
# pt_mean             12467 non-null float64
# bun_mean            12467 non-null float64
# is_AKI              12467 non-null int64
# is_Betablocker      12467 non-null int64
# dtypes: float64(26), int64(8)
# memory usage: 3.2 MB

# %%
data.head()
# Out:
#    Unnamed: 0  subject_id  hadm_id     icu  amdission_age  gender  \
# 0           0       26264   163486  211181        58.5394       0
# 1           1       86580   145497  285183        53.3505       0
# 2           2       28410   146362  282162        80.7914       0
# 3           3       61683   197678  237242        61.1226       0
# 4           4       23626   166653  230856        61.6232       0
#
#    thirty_day_mort  heartrate_mean  meanbp_mean  sysbp_mean       ...        \
# 0                1       88.464286    90.333333  143.200000       ...
# 1                1      115.125000    80.260870  111.217391       ...
# 2                1       91.909091    70.035714  120.413793       ...
# 3                1      106.521739    76.772727  117.000000       ...
# 4                0       44.896552    73.180328  107.344262       ...
#
#    albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  ptt_mean  \
# 0      2.958234   10.588819         2.23498        15.400000  24.90000
# 1      2.958234   10.588819         0.40000         9.600000  38.96671
# 2      2.958234   10.588819         2.23498         6.866667  37.10000
# 3      3.000000   10.588819         0.20000        12.000000  27.30000
# 4      2.958234   10.588819         0.70000        11.866667  26.10000
#
#    inr_mean    pt_mean  bun_mean  is_AKI  is_Betablocker
# 0  1.200000  13.200000       8.0       0               1
# 1  1.625585  16.776565      18.0       0               0
# 2  1.300000  15.100000      18.0       1               0
# 3  1.100000  11.400000     132.5       1               0
# 4  1.100000  13.100000      21.0       0               0
#
# [5 rows x 34 columns]

# %%
subdata_bb = data[data['is_Betablocker'] == 1]

# %%
subdata_bb.shape
# Out:
# (5997, 34)

# %%
subdata_bb.to_csv("/Users/joudsi/Desktop/17.07.19/subdata_bb.csv")

# %%
subdata_not_bb = data[data['is_Betablocker'] == 0]

# %%
subdata_not_bb.shape
# Out:
# (6470, 34)

# %%
subdata_not_bb.to_csv("/Users/joudsi/Desktop/17.07.19/subdata_not_bb.csv")

# %% [markdown]
# # Clustering for BB patients

# %%
data_bb = pd.read_csv('/Users/joudsi/Desktop/17.07.19/subdata_bb.csv')

# %%
data_bb.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  subject_id  hadm_id     icu  amdission_age  \
# 0           0             0       26264   163486  211181        58.5394
# 1           7             7       58528   114518  276469        88.9898
# 2           8             8       30317   149968  291779        84.5962
# 3           9             9       70467   138979  220814        60.5951
# 4          11            11       20549   116754  204636        57.6017
#
#    gender  thirty_day_mort  heartrate_mean  meanbp_mean       ...        \
# 0       0                1       88.464286    90.333333       ...
# 1       0                0       70.500000    83.904762       ...
# 2       0                0       65.162162    84.476190       ...
# 3       0                0       74.294118    67.117647       ...
# 4       1                0       88.880000    74.728393       ...
#
#    albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  ptt_mean  \
# 0      2.958234   10.588819         2.23498        15.400000  24.90000
# 1      2.958234   10.588819         0.50000        11.800000  38.96671
# 2      2.958234   10.588819         2.23498         9.900000  57.95000
# 3      2.000000   10.588819        11.60000         9.500000  36.80000
# 4      2.958234   10.588819         2.23498         9.888889  33.30000
#
#    inr_mean    pt_mean  bun_mean  is_AKI  is_Betablocker
# 0  1.200000  13.200000       8.0       0               1
# 1  1.625585  16.776565      12.0       0               1
# 2  1.075000  12.525000      67.0       0               1
# 3  2.000000  21.650000      32.5       0               1
# 4  1.533333  15.433333      15.5       0               1
#
# [5 rows x 35 columns]

# %%
subdata_bb = data_bb[['amdission_age',
       'gender', 'heartrate_mean', 'meanbp_mean',
       'sysbp_mean', 'tempc_mean', 'spo2_mean', 'resprate_mean',
       'diasbp_mean', 'creatinine_mean', 'potassium_mean', 'sodium_mean',
       'chloride_mean', 'bicarbonate_mean', 'hematocrit_mean', 'wbc_mean',
       'glucose_mean', 'lactate_mean', 'aniongap_mean', 'albumin_mean',
       'bands_mean', 'bilirubin_mean', 'hemoglobin_mean', 'ptt_mean',
       'inr_mean', 'pt_mean', 'bun_mean']]
subdata_bb_norm = (subdata_bb - subdata_bb.min()) / (subdata_bb.max() - subdata_bb.min())

# %% [markdown]
# ### Elbow method to determine the best K

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(subdata_bb_norm)
    Sum_of_squared_distances.append(km.inertia_)

# %%
import matplotlib.pyplot as plt

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ### Start clustering based on the best K-value

# %%
from sklearn.cluster import KMeans
from sklearn import datasets
model=KMeans(n_clusters=5)
model.fit(subdata_bb_norm)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
model.labels_
# Out:
# array([4, 4, 2, ..., 4, 4, 0], dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[4.70028901e-01, 1.11577414e-14, 4.85131339e-01, 3.99066160e-01,
#         3.94803980e-01, 6.79686252e-01, 9.38615816e-01, 3.78760157e-01,
#         4.25936640e-01, 9.96552872e-02, 2.89383581e-01, 5.34258059e-01,
#         4.99113251e-01, 3.87337864e-01, 3.98024098e-01, 6.76681806e-02,
#         1.39405445e-01, 1.11468088e-01, 2.37535290e-01, 4.41244049e-01,
#         1.44259655e-01, 6.65966888e-02, 4.11953710e-01, 1.82278006e-01,
#         3.23333797e-02, 7.87623588e-02, 1.64383887e-01],
#        [5.35321048e-01, 1.00000000e+00, 4.71786736e-01, 4.79753010e-01,
#         4.83976460e-01, 6.87129446e-01, 9.43552860e-01, 3.61691406e-01,
#         4.75018945e-01, 6.59619827e-02, 2.56241746e-01, 5.54614954e-01,
#         5.05626766e-01, 4.15800319e-01, 4.52587024e-01, 7.09566192e-02,
#         1.51640410e-01, 9.68031699e-02, 2.21635819e-01, 4.74278175e-01,
#         1.37946952e-01, 3.72151009e-02, 4.62873947e-01, 1.41114026e-01,
#         2.38054567e-02, 5.85623251e-02, 1.13824791e-01],
#        [8.12041856e-01, 1.72084569e-14, 3.63164581e-01, 3.31777747e-01,
#         3.75985294e-01, 6.39894100e-01, 9.34134919e-01, 3.54875246e-01,
#         3.35300487e-01, 8.82913749e-02, 2.88781630e-01, 5.50098416e-01,
#         5.05937504e-01, 4.16602069e-01, 4.38914869e-01, 7.45514216e-02,
#         1.40451429e-01, 9.98140701e-02, 2.22165494e-01, 4.62402079e-01,
#         1.42614124e-01, 3.61986911e-02, 4.46656045e-01, 1.94351101e-01,
#         3.28986330e-02, 7.69894066e-02, 1.86363805e-01],
#        [8.30325318e-01, 1.00000000e+00, 3.66367501e-01, 3.39000833e-01,
#         4.05023011e-01, 6.41257664e-01, 9.38493100e-01, 3.48363829e-01,
#         3.24052041e-01, 7.22857322e-02, 2.78922512e-01, 5.53258511e-01,
#         5.03368531e-01, 4.14445305e-01, 4.39822904e-01, 7.38398868e-02,
#         1.41499924e-01, 1.01342548e-01, 2.28867089e-01, 4.63015487e-01,
#         1.41979505e-01, 3.53018297e-02, 4.44013522e-01, 1.82777299e-01,
#         3.12974983e-02, 7.46311470e-02, 1.62095804e-01],
#        [6.24441440e-01, 9.49240686e-15, 3.92367841e-01, 5.29397114e-01,
#         5.40205814e-01, 6.72728121e-01, 9.38547752e-01, 3.47399607e-01,
#         5.18533339e-01, 6.15552553e-02, 2.56763213e-01, 5.65339527e-01,
#         4.96411741e-01, 4.42156229e-01, 6.01779931e-01, 7.01875486e-02,
#         1.52584186e-01, 9.44996197e-02, 2.17275579e-01, 5.20239565e-01,
#         1.37743433e-01, 3.32302914e-02, 6.26346887e-01, 1.32771567e-01,
#         2.21819068e-02, 5.68078494e-02, 1.09191381e-01]])

# %%
md=pd.Series(model.labels_)
subdata_bb_norm['clust']=md
subdata_bb_norm.head()
# Out:
#    amdission_age  gender  heartrate_mean  meanbp_mean  sysbp_mean  tempc_mean  \
# 0       0.558335     0.0        0.420142     0.538685    0.607481    0.713859
# 1       0.967606     0.0        0.251775     0.467465    0.728568    0.684853
# 2       0.908553     0.0        0.201747     0.473796    0.747566    0.580397
# 3       0.585965     0.0        0.287335     0.281486    0.415570    0.588939
# 4       0.545732     1.0        0.424039     0.365803    0.367042    0.706385
#
#    spo2_mean  resprate_mean  diasbp_mean  creatinine_mean  ...    \
# 0   0.903968       0.346149     0.452554         0.032558  ...
# 1   0.905051       0.322675     0.400575         0.032558  ...
# 2   0.988272       0.180286     0.388677         0.213953  ...
# 3   0.950327       0.240689     0.301600         0.055814  ...
# 4   0.954789       0.324970     0.388354         0.037209  ...
#
#    aniongap_mean  albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  \
# 0       0.203187      0.466246    0.142273        0.041618         0.820529
# 1       0.131474      0.466246    0.142273        0.007797         0.555009
# 2       0.298805      0.466246    0.142273        0.041618         0.414874
# 3       0.215139      0.238095    0.142273        0.224172         0.385372
# 4       0.155378      0.466246    0.142273        0.041618         0.414054
#
#    ptt_mean  inr_mean   pt_mean  bun_mean  clust
# 0  0.065721  0.014585  0.035408  0.026851      4
# 1  0.170775  0.030103  0.073783  0.046379      4
# 2  0.312547  0.010027  0.028165  0.314890      2
# 3  0.154593  0.043756  0.126073  0.146461      0
# 4  0.128454  0.026740  0.059371  0.063466      1
#
# [5 rows x 28 columns]

# %%
subdata_bb_norm['is_AKI']= data_bb['is_AKI']

# %%
subdata_bb_norm.head(10)
# Out:
#    amdission_age  gender  heartrate_mean  meanbp_mean  sysbp_mean  tempc_mean  \
# 0       0.558335     0.0        0.420142     0.538685    0.607481    0.713859
# 1       0.967606     0.0        0.251775     0.467465    0.728568    0.684853
# 2       0.908553     0.0        0.201747     0.473796    0.747566    0.580397
# 3       0.585965     0.0        0.287335     0.281486    0.415570    0.588939
# 4       0.545732     1.0        0.424039     0.365803    0.367042    0.706385
# 5       0.320255     1.0        0.614990     0.329273    0.333942    0.689836
# 6       0.957568     0.0        0.597882     0.508615    0.393588    0.544096
# 7       0.896536     0.0        0.275652     0.254333    0.336593    0.613496
# 8       0.518038     1.0        0.381154     0.501756    0.555573    0.769379
# 9       1.000000     1.0        0.530782     0.344951    0.412283    0.808171
#
#    spo2_mean  resprate_mean  diasbp_mean  creatinine_mean   ...    \
# 0   0.903968       0.346149     0.452554         0.032558   ...
# 1   0.905051       0.322675     0.400575         0.032558   ...
# 2   0.988272       0.180286     0.388677         0.213953   ...
# 3   0.950327       0.240689     0.301600         0.055814   ...
# 4   0.954789       0.324970     0.388354         0.037209   ...
# 5   0.935043       0.473174     0.374938         0.025581   ...
# 6   0.860000       0.487780     0.512280         0.093023   ...
# 7   0.992593       0.232354     0.316499         0.244961   ...
# 8   0.985185       0.253968     0.430876         0.044186   ...
# 9   0.932444       0.477072     0.293761         0.062016   ...
#
#    albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  ptt_mean  \
# 0      0.466246    0.142273        0.041618         0.820529  0.065721
# 1      0.466246    0.142273        0.007797         0.555009  0.170775
# 2      0.466246    0.142273        0.041618         0.414874  0.312547
# 3      0.238095    0.142273        0.224172         0.385372  0.154593
# 4      0.466246    0.142273        0.041618         0.414054  0.128454
# 5      0.466246    0.142273        0.038986         0.269822  0.123724
# 6      0.380952    0.133627        0.013645         0.650891  0.135922
# 7      0.690476    0.142273        0.023392         0.496005  0.249440
# 8      0.466246    0.142273        0.041618         0.675476  0.051531
# 9      0.466246    0.016153        0.019493         0.763983  0.167662
#
#    inr_mean   pt_mean  bun_mean  clust  is_AKI
# 0  0.014585  0.035408  0.026851      4       0
# 1  0.030103  0.073783  0.046379      4       0
# 2  0.010027  0.028165  0.314890      2       0
# 3  0.043756  0.126073  0.146461      0       0
# 4  0.026740  0.059371  0.063466      1       0
# 5  0.020662  0.059371  0.056143      1       0
# 6  0.029170  0.063305  0.246542      4       0
# 7  0.268611  0.613019  0.518308      2       1
# 8  0.010939  0.028970  0.041497      1       1
# 9  0.051048  0.092811  0.165175      3       0
#
# [10 rows x 29 columns]

# %%
import seaborn as sns
% matplotlib inline

sns.countplot(x="is_AKI", hue="clust",data=subdata_bb_norm)

# %%
subdata_bb_norm.groupby('clust').mean()
# Out:
#        amdission_age  gender  heartrate_mean  meanbp_mean  sysbp_mean  \
# clust
# 0           0.470029     0.0        0.485131     0.399066    0.394804
# 1           0.535321     1.0        0.471787     0.479753    0.483976
# 2           0.812042     0.0        0.363165     0.331778    0.375985
# 3           0.830325     1.0        0.366368     0.339001    0.405023
# 4           0.624441     0.0        0.392368     0.529397    0.540206
#
#        tempc_mean  spo2_mean  resprate_mean  diasbp_mean  creatinine_mean  \
# clust
# 0        0.679686   0.938616       0.378760     0.425937         0.099655
# 1        0.687129   0.943553       0.361691     0.475019         0.065962
# 2        0.639894   0.934135       0.354875     0.335300         0.088291
# 3        0.641258   0.938493       0.348364     0.324052         0.072286
# 4        0.672728   0.938548       0.347400     0.518533         0.061555
#
#          ...     aniongap_mean  albumin_mean  bands_mean  bilirubin_mean  \
# clust    ...
# 0        ...          0.237535      0.441244    0.144260        0.066597
# 1        ...          0.221636      0.474278    0.137947        0.037215
# 2        ...          0.222165      0.462402    0.142614        0.036199
# 3        ...          0.228867      0.463015    0.141980        0.035302
# 4        ...          0.217276      0.520240    0.137743        0.033230
#
#        hemoglobin_mean  ptt_mean  inr_mean   pt_mean  bun_mean    is_AKI
# clust
# 0             0.411954  0.182278  0.032333  0.078762  0.164384  0.447589
# 1             0.462874  0.141114  0.023805  0.058562  0.113825  0.363273
# 2             0.446656  0.194351  0.032899  0.076989  0.186364  0.507765
# 3             0.444014  0.182777  0.031297  0.074631  0.162096  0.486407
# 4             0.626347  0.132772  0.022182  0.056808  0.109191  0.354839
#
# [5 rows x 28 columns]

# %%
subdata_bb_norm.to_csv("/Users/joudsi/Desktop/17.07.19/subdata_bb_norm_clustered.csv")

# %% [markdown]
# # Clustering for not BB patients

# %%
data_not_bb = pd.read_csv('/Users/joudsi/Desktop/17.07.19/subdata_not_bb.csv')

# %%
data_not_bb.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  subject_id  hadm_id     icu  amdission_age  \
# 0           1             1       86580   145497  285183        53.3505
# 1           2             2       28410   146362  282162        80.7914
# 2           3             3       61683   197678  237242        61.1226
# 3           4             4       23626   166653  230856        61.6232
# 4           5             5       29007   115451  285787        91.4000
#
#    gender  thirty_day_mort  heartrate_mean  meanbp_mean       ...        \
# 0       0                1      115.125000    80.260870       ...
# 1       0                1       91.909091    70.035714       ...
# 2       0                1      106.521739    76.772727       ...
# 3       0                0       44.896552    73.180328       ...
# 4       0                0       57.541667    63.136364       ...
#
#    albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  ptt_mean  \
# 0      2.958234   10.588819         0.40000         9.600000  38.96671
# 1      2.958234   10.588819         2.23498         6.866667  37.10000
# 2      3.000000   10.588819         0.20000        12.000000  27.30000
# 3      2.958234   10.588819         0.70000        11.866667  26.10000
# 4      2.958234   16.000000         2.23498        12.250000  30.55000
#
#    inr_mean    pt_mean  bun_mean  is_AKI  is_Betablocker
# 0  1.625585  16.776565      18.0       0               0
# 1  1.300000  15.100000      18.0       1               0
# 2  1.100000  11.400000     132.5       1               0
# 3  1.100000  13.100000      21.0       0               0
# 4  2.300000  23.800000      51.0       1               0
#
# [5 rows x 35 columns]

# %%
subdata_not_bb = data_not_bb[['amdission_age',
       'gender', 'heartrate_mean', 'meanbp_mean',
       'sysbp_mean', 'tempc_mean', 'spo2_mean', 'resprate_mean',
       'diasbp_mean', 'creatinine_mean', 'potassium_mean', 'sodium_mean',
       'chloride_mean', 'bicarbonate_mean', 'hematocrit_mean', 'wbc_mean',
       'glucose_mean', 'lactate_mean', 'aniongap_mean', 'albumin_mean',
       'bands_mean', 'bilirubin_mean', 'hemoglobin_mean', 'ptt_mean',
       'inr_mean', 'pt_mean', 'bun_mean']]
subdata_not_bb_norm = (subdata_not_bb - subdata_not_bb.min()) / (subdata_not_bb.max() - subdata_not_bb.min())

# %% [markdown]
# ### Elbow method to determine the best K

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(subdata_not_bb_norm)
    Sum_of_squared_distances.append(km.inertia_)

# %%
import matplotlib.pyplot as plt

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ### Start clustering based on the best K-value

# %%
model=KMeans(n_clusters=4)
model.fit(subdata_not_bb_norm)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
model.labels_
# Out:
# array([2, 0, 0, ..., 1, 3, 1], dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[7.88821653e-01, 8.10462808e-15, 3.92030614e-01, 4.38369491e-01,
#         4.68360691e-01, 5.89653337e-01, 9.60861868e-01, 3.55107054e-01,
#         4.23303120e-01, 7.51768719e-02, 4.25786275e-01, 4.91681873e-01,
#         4.96560141e-01, 4.06569575e-01, 3.90991754e-01, 2.08853604e-02,
#         1.44594578e-01, 9.22513495e-02, 2.51525190e-01, 4.05235354e-01,
#         1.42091957e-01, 2.97136098e-02, 4.12320749e-01, 1.97372783e-01,
#         3.02857435e-02, 6.12679168e-02, 1.45230391e-01],
#        [4.24100627e-01, 1.00000000e+00, 4.74190619e-01, 4.89951399e-01,
#         4.81528842e-01, 6.27935500e-01, 9.64608832e-01, 3.58368270e-01,
#         5.03293935e-01, 4.65088273e-02, 3.63065090e-01, 4.85529906e-01,
#         4.95273341e-01, 4.07181848e-01, 3.97011922e-01, 1.92458948e-02,
#         1.40312974e-01, 8.22158727e-02, 2.34925875e-01, 4.14577364e-01,
#         1.44382333e-01, 2.97515530e-02, 4.24265792e-01, 1.66728040e-01,
#         2.44057577e-02, 5.06090564e-02, 7.37969310e-02],
#        [4.18830132e-01, 7.43849426e-15, 4.66432134e-01, 5.16740811e-01,
#         5.11454537e-01, 6.40144064e-01, 9.62144597e-01, 3.54628549e-01,
#         5.40472134e-01, 5.53052871e-02, 3.96718455e-01, 4.83501907e-01,
#         4.82282350e-01, 4.31230217e-01, 4.48255617e-01, 1.87198919e-02,
#         1.41868005e-01, 8.84217490e-02, 2.34085250e-01, 4.34847780e-01,
#         1.42656182e-01, 2.98824845e-02, 4.87895003e-01, 1.61863703e-01,
#         2.30908458e-02, 4.81539882e-02, 8.51241769e-02],
#        [8.26768857e-01, 1.00000000e+00, 3.95741756e-01, 4.34046921e-01,
#         4.83906504e-01, 5.81568866e-01, 9.60714909e-01, 3.39807850e-01,
#         4.04240869e-01, 6.01305810e-02, 4.08492440e-01, 4.94184161e-01,
#         4.91205387e-01, 4.21124676e-01, 3.87292385e-01, 2.07001762e-02,
#         1.48027512e-01, 8.81889425e-02, 2.48513357e-01, 4.16173044e-01,
#         1.39882468e-01, 2.05813268e-02, 4.02145894e-01, 1.86061581e-01,
#         2.74024115e-02, 5.66703836e-02, 1.25985901e-01]])

# %%
md=pd.Series(model.labels_)
subdata_not_bb_norm['clust']=md
subdata_not_bb_norm.head()
# Out:
#    amdission_age  gender  heartrate_mean  meanbp_mean  sysbp_mean  tempc_mean  \
# 0       0.488717     0.0        0.622181     0.513765    0.467144    0.682906
# 1       0.857449     0.0        0.442255     0.419493    0.533017    0.526844
# 2       0.593153     0.0        0.555505     0.481606    0.508564    0.585988
# 3       0.599880     0.0        0.077902     0.448485    0.439401    0.344937
# 4       1.000000     0.0        0.175903     0.355883    0.511169    0.557659
#
#    spo2_mean  resprate_mean  diasbp_mean  creatinine_mean  ...    \
# 0   0.952925       0.495046     0.614398         0.041051  ...
# 1   0.981238       0.316202     0.323825         0.012315  ...
# 2   0.989232       0.462089     0.521004         0.190887  ...
# 3   0.996756       0.188622     0.421801         0.025999  ...
# 4   0.936510       0.400152     0.285158         0.073892  ...
#
#    aniongap_mean  albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  \
# 0       0.155556      0.419392    0.141012        0.003713         0.358974
# 1       0.122222      0.419392    0.141012        0.026423         0.183761
# 2       0.466667      0.428571    0.141012        0.001238         0.512821
# 3       0.166667      0.419392    0.141012        0.007426         0.504274
# 4       0.266667      0.419392    0.220588        0.026423         0.528846
#
#    ptt_mean  inr_mean   pt_mean  bun_mean  clust
# 0  0.181170  0.026126  0.053138  0.060837      2
# 1  0.167404  0.015823  0.041222  0.060837      0
# 2  0.095133  0.009494  0.014925  0.496198      0
# 3  0.086283  0.009494  0.027008  0.072243      0
# 4  0.119100  0.047468  0.103056  0.186312      0
#
# [5 rows x 28 columns]

# %%
subdata_not_bb_norm['is_AKI'] = data_not_bb['is_AKI']

# %%
subdata_not_bb_norm.head(10)
# Out:
#    amdission_age  gender  heartrate_mean  meanbp_mean  sysbp_mean  tempc_mean  \
# 0       0.488717     0.0        0.622181     0.513765    0.467144    0.682906
# 1       0.857449     0.0        0.442255     0.419493    0.533017    0.526844
# 2       0.593153     0.0        0.555505     0.481606    0.508564    0.585988
# 3       0.599880     0.0        0.077902     0.448485    0.439401    0.344937
# 4       1.000000     0.0        0.175903     0.355883    0.511169    0.557659
# 5       0.799402     0.0        0.206581     0.481857    0.503448    0.668327
# 6       0.588504     1.0        0.367755     0.543629    0.641832    0.679924
# 7       0.628669     0.0        0.328430     0.442213    0.676892    0.646525
# 8       0.779984     1.0        0.384665     0.389901    0.389287    0.588473
# 9       0.132262     0.0        0.415209     0.380749    0.373663    0.616306
#
#    spo2_mean  resprate_mean  diasbp_mean  creatinine_mean   ...    \
# 0   0.952925       0.495046     0.614398         0.041051   ...
# 1   0.981238       0.316202     0.323825         0.012315   ...
# 2   0.989232       0.462089     0.521004         0.190887   ...
# 3   0.996756       0.188622     0.421801         0.025999   ...
# 4   0.936510       0.400152     0.285158         0.073892   ...
# 5   0.982380       0.243293     0.473912         0.065681   ...
# 6   0.979987       0.256728     0.504093         0.020525   ...
# 7   0.971857       0.220475     0.357042         0.032841   ...
# 8   0.976018       0.452545     0.431751         0.064794   ...
# 9   0.958603       0.281707     0.423420         0.034209   ...
#
#    albumin_mean  bands_mean  bilirubin_mean  hemoglobin_mean  ptt_mean  \
# 0      0.419392    0.141012        0.003713         0.358974  0.181170
# 1      0.419392    0.141012        0.026423         0.183761  0.167404
# 2      0.428571    0.141012        0.001238         0.512821  0.095133
# 3      0.419392    0.141012        0.007426         0.504274  0.086283
# 4      0.419392    0.220588        0.026423         0.528846  0.119100
# 5      0.419392    0.141012        0.007426         0.598291  0.254425
# 6      0.419392    0.141012        0.026423         0.482051  0.083333
# 7      0.648352    0.141012        0.002475         0.549145  0.519358
# 8      0.419392    0.141012        0.026423         0.426579  0.181170
# 9      0.419392    0.141012        0.026423         0.410256  0.102507
#
#    inr_mean   pt_mean  bun_mean  clust  is_AKI
# 0  0.026126  0.053138  0.060837      2       0
# 1  0.015823  0.041222  0.060837      0       1
# 2  0.009494  0.014925  0.496198      0       1
# 3  0.009494  0.027008  0.072243      0       0
# 4  0.047468  0.103056  0.186312      0       1
# 5  0.120253  0.240583  0.089354      0       0
# 6  0.004747  0.008529  0.031686      1       0
# 7  0.010549  0.029614  0.044360      0       0
# 8  0.026126  0.053138  0.116858      3       0
# 9  0.015823  0.038735  0.049430      2       0
#
# [10 rows x 29 columns]

# %%
sns.countplot(x="is_AKI", hue="clust",data=subdata_not_bb_norm)

# %%
subdata_not_bb_norm.groupby('clust').mean()
# Out:
#        amdission_age  gender  heartrate_mean  meanbp_mean  sysbp_mean  \
# clust
# 0           0.788822     0.0        0.392031     0.438369    0.468361
# 1           0.424101     1.0        0.474191     0.489951    0.481529
# 2           0.418830     0.0        0.466432     0.516741    0.511455
# 3           0.826769     1.0        0.395742     0.434047    0.483907
#
#        tempc_mean  spo2_mean  resprate_mean  diasbp_mean  creatinine_mean  \
# clust
# 0        0.589653   0.960862       0.355107     0.423303         0.075177
# 1        0.627935   0.964609       0.358368     0.503294         0.046509
# 2        0.640144   0.962145       0.354629     0.540472         0.055305
# 3        0.581569   0.960715       0.339808     0.404241         0.060131
#
#          ...     aniongap_mean  albumin_mean  bands_mean  bilirubin_mean  \
# clust    ...
# 0        ...          0.251525      0.405235    0.142092        0.029714
# 1        ...          0.234926      0.414577    0.144382        0.029752
# 2        ...          0.234085      0.434848    0.142656        0.029882
# 3        ...          0.248513      0.416173    0.139882        0.020581
#
#        hemoglobin_mean  ptt_mean  inr_mean   pt_mean  bun_mean    is_AKI
# clust
# 0             0.412321  0.197373  0.030286  0.061268  0.145230  0.493347
# 1             0.424266  0.166728  0.024406  0.050609  0.073797  0.295935
# 2             0.487895  0.161864  0.023091  0.048154  0.085124  0.337437
# 3             0.402146  0.186062  0.027402  0.056670  0.125986  0.450394
#
# [4 rows x 28 columns]

# %%
subdata_not_bb_norm.to_csv("/Users/joudsi/Desktop/17.07.19/subdata_not_bb_norm_clustered.csv")
